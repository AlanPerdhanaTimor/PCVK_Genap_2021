# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanPerdhanaTimor/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#akses google drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/folder gambar/16224_n.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %% [markdown]
# **TUGAS**
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
#
# =
# - iya, ukuran pixelnya juga berubah seiring berubahnya ukuran gambarnya
# 2. Tampilkan image dalam channel Red-Green dan Green-Blue saja!
#
# =
# - di bawah
# 3. Tampilkan image baris ke 10-100, kolom 10-100!
#
# =
# - di bawah
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!
#
# =
# - di bawah
#
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!
#
# =
# - di bawah
# 6. Tampilkan image dengan posisi terbalik!
#
# =
# - di bawah

# %%
#tugas no.2 red-green
img6 = img
img6[:,:,0] = np.zeros([img6.shape[0], img6.shape[1]])
plt.imshow(img6)

# %%
#tugas 2 red-green
imgx2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)


imgx2[:,:,2] = np.zeros([imgx2.shape[0], imgx2.shape[1]])
plt.imshow(imgx2)

# %%
#tugas no.3
img2 = img[10:100, 10:100]
plt.imshow(img2)

# %%
#tugas 4
plt.imshow(img3[5:30])

# %%
#tugas 5
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(img3, pt1=(354,0), pt2=(40,170), color=(0,255,0), thickness=10)
cv.rectangle(img3, pt1=(300,200), pt2=(510,150), color=(0,255,0), thickness=10)
cv.rectangle(img3, pt1=(250,500), pt2=(510,150), color=(0,255,0), thickness=10)
cv.rectangle(img3, pt1=(400,700), pt2=(510,150), color=(0,255,0), thickness=10)
cv.rectangle(img3, pt1=(500,700), pt2=(600,600), color=(0,255,0), thickness=10)

plt.imshow(img3)

# %%
#tugas no.6
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
plt.imshow(img5)

# %%
img_gray = cv.imread('/content/drive/MyDrive/folder gambar/16224_n.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap= 'gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/folder gambar/mandrill2.tiff',img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10)) #bisa diubah ukurannya (10,10), sesuai keinginannya
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik-titik pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-2)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices= np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 buat nunjukan bahwa tiap titik 3 dibuat 3 channel yg mewakili R,G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Pertanyaan
# 1. Apakah perbedaan gambar yang ditampilkan dengan dan tanpa matplotlib ?
#
# =
# - perbedaanya adalah jika menggunakan matplotlib kita sudah disuguhkan gambar kita yang sudah ada ukuran panjang dan lebarnya (yang bagian kiri dan bawah)
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
#
# =
#  - perbedaannya ada pengaruh ukuran file gambar, yang dimana int16 memiliki kapasitas file lebih sedikit ketimbang int32
#
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
# ![image.png](data:image/png;base64,...)
#
# =
# - untuk menampilkan gambar pada google collab, kita perlu menggunakan pacthes
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# =
# - untuk men-load gambar, read dan write gambar

# %% [markdown]
# TUGAS
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 1. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).
# 2. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
# 3. Tulis nama file pada file citra dari soal no.2. Gunakan font, ukuran font, dan
# warna font yang sesuai keinginan anda.
# Tunjukkan code program anda pada bapak/ibu dosen

# %%
import cv2 as cv
imgt = cv.imread('/content/drive/MyDrive/folder gambar/WhatsApp Image 2021-02-16 at 12.34.11.jpeg')
plt.imshow(imgt)

# %%
#tugas no.1
cv.rectangle(imgt,pt1=(300,400),pt2=(600,900),color=(0,0,255), thickness=10)
plt.imshow(imgt)

# %%
#tugas no.1
cv.circle(imgt,center=(500,600),radius=160,color=(255,0,0),thickness=8)
plt.imshow(imgt)

# %%
#tugas no.2
cv.rectangle(imgt,pt1=(50,1100),pt2=(210,1200),color=(0,0,255), thickness=10)
plt.imshow(imgt)

# %%
#tugas no.3
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(imgt, text='halo',org=(10,200),fontFace=font,fontScale=5,color=(255,0,0),thickness=6,lineType=cv.LINE_4)
plt.imshow(imgt)
